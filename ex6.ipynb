# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('daily-min-temperatures.csv',parse_dates=['Date'],index_col='Date')
df
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8
# ...          ...
# 1990-12-27  14.0
# 1990-12-28  13.6
# 1990-12-29  13.5
# 1990-12-30  15.7
# 1990-12-31  13.0
#
# [3650 rows x 1 columns]

# %%
df.head(5)
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8

# %%
df.tail(5)
# Out:
#             Temp
# Date
# 1990-12-27  14.0
# 1990-12-28  13.6
# 1990-12-29  13.5
# 1990-12-30  15.7
# 1990-12-31  13.0

# %%
df.shape
# Out:
# (3650, 1)

# %%
df.columns
# Out:
# Index(['Temp'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3650 entries, 1981-01-01 to 1990-12-31
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Temp    3650 non-null   float64
# dtypes: float64(1)
# memory usage: 57.0 KB

# %%
df.describe()
# Out:
#               Temp
# count  3650.000000
# mean     11.177753
# std       4.071837
# min       0.000000
# 25%       8.300000
# 50%      11.000000
# 75%      14.000000
# max      26.300000

# %%
df.isnull().sum()
# Out:
# Temp    0
# dtype: int64

# %%
df.plot(title='Daily Minimum Temperature',figsize=(10,8),legend=None)
plt.xlabel('Date')
plt.ylabel('Temperature')
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

fig,axes=plt.subplots(2,1,figsize=(10,8))
plot_acf(df['Temp'],lags=30,ax=axes[0],title='Autocorrelation (ACF)')
plot_pacf(df['Temp'],lags=30,ax=axes[1],title='Partial Autocorrelation (PACF)')
plt.tight_layout()
plt.show()
