# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
date_range=pd.date_range(start='1/1/2024',end='1/31/2024',freq='D')
date_range
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06', '2024-01-07', '2024-01-08',
#                '2024-01-09', '2024-01-10', '2024-01-11', '2024-01-12',
#                '2024-01-13', '2024-01-14', '2024-01-15', '2024-01-16',
#                '2024-01-17', '2024-01-18', '2024-01-19', '2024-01-20',
#                '2024-01-21', '2024-01-22', '2024-01-23', '2024-01-24',
#                '2024-01-25', '2024-01-26', '2024-01-27', '2024-01-28',
#                '2024-01-29', '2024-01-30', '2024-01-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
temp_data=np.random.normal(loc=10,scale=5,size=len(date_range))
temp_data
# Out:
# array([17.82482306, 13.35232042, 12.09732612, 14.88064983, 11.28763042,
#         4.30287383,  8.10005646,  5.35162438, 15.06385538, 12.44479524,
#         3.23666907, 10.67205086,  0.68120582,  8.58391806, -2.93118637,
#        16.19285146,  4.57104491, 17.09800508, 10.54810296,  9.94890929,
#         8.32298169,  6.74942238,  4.81815582, 21.52887902,  7.02316766,
#         8.71850188,  4.12440598, 12.23111804,  5.85399257, 12.75007316,
#        18.94273604])

# %%
temp_df=pd.DataFrame({'Date':date_range,'Temperature':temp_data})
temp_df
# Out:
#          Date  Temperature
# 0  2024-01-01    17.824823
# 1  2024-01-02    13.352320
# 2  2024-01-03    12.097326
# 3  2024-01-04    14.880650
# 4  2024-01-05    11.287630
# 5  2024-01-06     4.302874
# 6  2024-01-07     8.100056
# 7  2024-01-08     5.351624
# 8  2024-01-09    15.063855
# 9  2024-01-10    12.444795
# 10 2024-01-11     3.236669
# 11 2024-01-12    10.672051
# 12 2024-01-13     0.681206
# 13 2024-01-14     8.583918
# 14 2024-01-15    -2.931186
# 15 2024-01-16    16.192851
# 16 2024-01-17     4.571045
# 17 2024-01-18    17.098005
# 18 2024-01-19    10.548103
# 19 2024-01-20     9.948909
# 20 2024-01-21     8.322982
# 21 2024-01-22     6.749422
# 22 2024-01-23     4.818156
# 23 2024-01-24    21.528879
# 24 2024-01-25     7.023168
# 25 2024-01-26     8.718502
# 26 2024-01-27     4.124406
# 27 2024-01-28    12.231118
# 28 2024-01-29     5.853993
# 29 2024-01-30    12.750073
# 30 2024-01-31    18.942736

# %%
temp_df.set_index('Date',inplace=True)

# %%
temp_df.head()
# Out:
#             Temperature
# Date
# 2024-01-01    17.824823
# 2024-01-02    13.352320
# 2024-01-03    12.097326
# 2024-01-04    14.880650
# 2024-01-05    11.287630

# %%
plt.figure(figsize=(8,3))
plt.plot(temp_df.index,temp_df['Temperature'])
plt.title('Daily temp in Jan24')
plt.xlabel('Date')
plt.ylabel('Temp in Celsius')
plt.show()

# %%
plt.figure(figsize=(8,3))
plt.scatter(temp_df.index,temp_df['Temperature'])
plt.title('Daily temp in Jan24')
plt.xlabel('Date')
plt.ylabel('Temp in Celsius')
plt.show()

# %%
plt.figure(figsize=(8,3))
pd.plotting.autocorrelation_plot(temp_df['Temperature'])
plt.title("Autocorrelation plot")
plt.show()

# %%
plt.figure(figsize=(8,3))
plt.hist(temp_df['Temperature'],bins=10)
plt.title(' Histogram for Daily temp in Jan24')
plt.xlabel('Temp in Celsius')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8,3))
sns.kdeplot(temp_df['Temperature'],fill=True)
plt.title(' Density plot for Daily temp in Jan24')
plt.xlabel('Temp in Celsius')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(8,3))
sns.boxplot(x=temp_df['Temperature'])
plt.title(' Box and Whisker plot for Daily temp in Jan24')
plt.xlabel('Temp in Celsius')
plt.show()

# %%
plt.figure(figsize=(8, 3))
sns.heatmap(temp_df, cmap='coolwarm')
plt.title('Heatmap for Daily Temp in Jan24')
plt.xlabel('Days')
plt.show()
